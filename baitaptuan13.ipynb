# %%
#W11A1
def reverse(n):
    n = str(n)
    n = n[::-1]
    return int(n)

with open('input.txt' , 'r') as file:
    n = file.read()
n = int(n)
print(reverse(n))
# Out:
# 21

# %%
#W11A2
with open('input.txt' , 'r') as file:
    n = file.read()
n = int(n)
if n % 4 == 0:
    print("False")
else:
    print("True")
# Out:
# False

# %%
#11A3
with open('GodricGryffindor.txt' , 'r') as file:
    s = file.read()
print(s)
with open('HelgaHufflepuff.txt' , 'r') as file:
    s = file.read()
print(s)
with open('RowenaRavenclaw.txt' , 'r') as file:
    s = file.read()
print(s)
with open('SalazarSlytherin.txt' , 'r') as file:
    s = file.read()
print(s)
# Out:
# huy
# kien
# quan
# cuong
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 5
#       3     s = file.read()
#       4 print(s)
# ----> 5 with open('HelgaHufflepuff.txt' , 'r') as file:
#       6     s = file.read()
#       7 print(s)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'HelgaHufflepuff.txt'

# %%
#W11A4
with open('input.txt' , 'r') as file:
    arr1 = file.read().split()
with open('output.txt' , 'r') as file:
    arr2 = file.read().split()
ans1 , ans2 = "" , ""
for i in arr1:
    ans1 += i
for i in arr2:
    ans2 += i

ans1 = sorted(ans1.lower())
ans2 = sorted(ans2.lower())

if len(ans1) != len(ans2):
    print('False')
else:
    kt = True
    for i in range(len(arr1)):
        if ans1[i] != ans2[i]:
            print("False")
            kt = False
            break
    if kt:
        print("True")
# Out:
# ['1', '2', '3']
# ['2', '3', '4']
# False

# %%
#W11A5
